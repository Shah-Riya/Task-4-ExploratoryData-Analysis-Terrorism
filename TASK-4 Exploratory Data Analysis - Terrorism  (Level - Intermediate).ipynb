# %% [markdown]
# Data Science & Business Analytics Tasks
# TASK 4 : Exploratory Data Analysis - Terrorism (Level - Intermediate)
#
# Dataset: https://bit.ly/2TK5Xn5

# %%
#Import libraries from the packages
import pandas as pd
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading dataset
df = pd.read_csv(r"C:\Users\Riya\Desktop\GRIP INTERNSHIP\TASK 4\globalterrorismdb_0718dist.csv",encoding='latin1',low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#Retriving all the columns from the file
for i in df.columns:
    print (i,end=",")
# Out:
# eventid,iyear,imonth,iday,approxdate,extended,resolution,country,country_txt,region,region_txt,provstate,city,latitude,longitude,specificity,vicinity,location,summary,crit1,crit2,crit3,doubtterr,alternative,alternative_txt,multiple,success,suicide,attacktype1,attacktype1_txt,attacktype2,attacktype2_txt,attacktype3,attacktype3_txt,targtype1,targtype1_txt,targsubtype1,targsubtype1_txt,corp1,target1,natlty1,natlty1_txt,targtype2,targtype2_txt,targsubtype2,targsubtype2_txt,corp2,target2,natlty2,natlty2_txt,targtype3,targtype3_txt,targsubtype3,targsubtype3_txt,corp3,target3,natlty3,natlty3_txt,gname,gsubname,gname2,gsubname2,gname3,gsubname3,motive,guncertain1,guncertain2,guncertain3,individual,nperps,nperpcap,claimed,claimmode,claimmode_txt,claim2,claimmode2,claimmode2_txt,claim3,claimmode3,claimmode3_txt,compclaim,weaptype1,weaptype1_txt,weapsubtype1,weapsubtype1_txt,weaptype2,weaptype2_txt,weapsubtype2,weapsubtype2_txt,weaptype3,weaptype3_txt,weapsubtype3,weapsubtype3_txt,weaptype4,wea
# ...

# %%
#Returns tuple of shape (Rows, columns) of dataframe.
df.shape
# Out:
# (181691, 135)

# %%
#Displaying last 5 records
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#Prints information about a Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#View some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#Renaming columns name
df.rename(columns={'iyear':'YEAR','imonth':'MONTH', 'iday':'DAY', 'country_txt':'COUNTRY' })
# Out:
#              eventid  YEAR  MONTH  DAY approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             COUNTRY  region  ... addnotes  \
# ...

# %%
#Returns the first 5 rows of the dataframe
df.head(5).T
# Out:
#                        0             1             2             3  \
# eventid     197000000001  197000000002  197001000001  197001000002
# iyear               1970          1970          1970          1970
# imonth                 7             0             1             1
# iday                   2             0             0             0
# approxdate           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# INT_LOG                0             0            -9            -9
# INT_IDEO               0             1            -9            -9
# INT_MISC               0             1             1             1
# INT_ANY                0             1             1             1
# related              NaN           NaN           NaN           NaN
#
#                        4
# eventid     197001000003
# iyear               1970
# imonth                 1
# iday                   0
# approxdate           NaN
# ...

# %%
#Checking for null values
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#Printing necessary data
print("Country with the most attacks:",df['country_txt'].value_counts().idxmax())
print("Region with the most attacks:",df['region'].value_counts().idxmax())
print("year with the most attacks:",df['iyear'].value_counts().idxmax())
print("month with the most attacks:",df['imonth'].value_counts().idxmax())
print("day with the most attacks:",df['iday'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# Region with the most attacks: 10
# year with the most attacks: 2014
# month with the most attacks: 5
# day with the most attacks: 15

# %%
#Number of duplicate values in data set
df.duplicated().sum()
# Out:
# 0

# %%
#Filling 0 in null values 
df.fillna(0)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2          0         0          0
# 1       197000000002   1970       0     0          0         0          0
# 2       197001000001   1970       1     0          0         0          0
# 3       197001000002   1970       1     0          0         0          0
# 4       197001000003   1970       1     0          0         0          0
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31          0         0          0
# 181687  201712310029   2017      12    31          0         0          0
# 181688  201712310030   2017      12    31          0         0          0
# 181689  201712310031   2017      12    31          0         0          0
# 181690  201712310032   2017      12    31          0         0          0
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#Detecting missing values in the given series
df.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
#Dealing with data containing missing values is to skip rows with missing values in the dataset.
df.isnull().sum()
# Out:
# eventid       0
# iyear         0
# imonth        0
# iday          0
# approxdate    0
#              ..
# INT_LOG       0
# INT_IDEO      0
# INT_MISC      0
# INT_ANY       0
# related       0
# Length: 135, dtype: int64

# %%
#Null values are replaced with zero 
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2          0         0          0
# 1       197000000002   1970       0     0          0         0          0
# 2       197001000001   1970       1     0          0         0          0
# 3       197001000002   1970       1     0          0         0          0
# 4       197001000003   1970       1     0          0         0          0
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31          0         0          0
# 181687  201712310029   2017      12    31          0         0          0
# 181688  201712310030   2017      12    31          0         0          0
# 181689  201712310031   2017      12    31          0         0          0
# 181690  201712310032   2017      12    31          0         0          0
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#Returning the column labels of the given Dataframe
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#Finding out the data type of each column in the given dataframe
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
#Returning Series with number of distinct observations over requested axis
df.nunique()
# Out:
# eventid       177134
# iyear             47
# imonth            13
# iday              32
# approxdate      2211
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        13832
# Length: 135, dtype: int64

# %%
#Years in the dataset
df['iyear'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
#Counting each year in the dataset
df['iyear'].value_counts()
# Out:
# 2014    16794
# 2015    14861
# 2016    13530
# 2013    11926
# 2017    10853
# 2012     8470
# 2011     5048
# 1992     4832
# 2010     4818
# 2008     4756
# 2009     4706
# 1991     4405
# 1989     4147
# 1990     3648
# 1988     3471
# 1994     3295
# 1984     3198
# 2007     3190
# 1997     2996
# 1987     2989
# 1995     2920
# 1996     2909
# 2006     2716
# 1985     2680
# 1986     2680
# 1983     2670
# 1980     2561
# 1979     2533
# 1981     2469
# 1982     2408
# 2005     1985
# 2001     1883
# 2000     1772
# 1978     1455
# 1999     1341
# 2002     1310
# 1977     1292
# 2003     1263
# 2004     1137
# 1976      900
# 1998      891
# 1975      727
# 1970      643
# 1974      577
# 1972      551
# 1973      465
# 1971      463
# Name: iyear, dtype: int64

# %%
#Printing year in ascending order
df['iyear'].value_counts(dropna= False ).sort_index()
# Out:
# 1970      643
# 1971      463
# 1972      551
# 1973      465
# 1974      577
# 1975      727
# 1976      900
# 1977     1292
# 1978     1455
# 1979     2533
# 1980     2561
# 1981     2469
# 1982     2408
# 1983     2670
# 1984     3198
# 1985     2680
# 1986     2680
# 1987     2989
# 1988     3471
# 1989     4147
# 1990     3648
# 1991     4405
# 1992     4832
# 1994     3295
# 1995     2920
# 1996     2909
# 1997     2996
# 1998      891
# 1999     1341
# 2000     1772
# 2001     1883
# 2002     1310
# 2003     1263
# 2004     1137
# 2005     1985
# 2006     2716
# 2007     3190
# 2008     4756
# 2009     4706
# 2010     4818
# 2011     5048
# 2012     8470
# 2013    11926
# 2014    16794
# 2015    14861
# 2016    13530
# 2017    10853
# Name: iyear, dtype: int64

# %%
#Counting region in the dataset
df['region_txt'].value_counts()
# Out:
# Middle East & North Africa     49577
# South Asia                     44479
# South America                  18110
# Sub-Saharan Africa             17011
# Western Europe                 16482
# Southeast Asia                 11946
# Central America & Caribbean     9344
# Eastern Europe                  5117
# North America                   3450
# East Asia                        794
# Central Asia                     548
# Australasia & Oceania            276
# Name: region_txt, dtype: int64

# %%
#Counting city from the dataset
df['city'].value_counts()
# Out:
# Baghdad                     7589
# Unknown                     7534
# Karachi                     2651
# Lima                        2359
# Mosul                       2265
#                             ...
# Ramdi                          1
# Joh Ai Rong ((District))       1
# Darawo                         1
# Adaisseh                       1
# Janchijasa                     1
# Name: city, Length: 35060, dtype: int64

# %%
#Counting attack type from the dataset
df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      86843
# Armed Assault                          41107
# Assassination                          18819
# Hostage Taking (Kidnapping)            10671
# Facility/Infrastructure Attack         10186
# Unknown                                 6931
# Unarmed Assault                          986
# Hostage Taking (Barricade Incident)      962
# Hijacking                                629
# Name: attacktype1_txt, dtype: int64

# %%
#Finding the pairwise correlation of all columns in the dataframe
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.001362  0.017193  0.091682 -0.140325
# iyear      0.999996  1.000000 -0.001215  0.017114  0.091673 -0.140310
# imonth     0.001362 -0.001215  1.000000  0.004008 -0.000244 -0.006197
# iday       0.017193  0.017114  0.004008  1.000000 -0.003361  0.003575
# extended   0.091682  0.091673 -0.000244 -0.003361  1.000000 -0.020928
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.074460 -0.074448 -0.002462  0.000497 -0.404274  0.000594
# INT_LOG   -0.136935 -0.136935 -0.002374 -0.000918  0.072311  0.071768
# INT_IDEO  -0.126729 -0.126730 -0.002156 -0.000880  0.075332  0.069323
# INT_MISC  -0.082780 -0.082774 -0.002372 -0.002320  0.024063  0.212350
# INT_ANY   -0.171671 -0.171660 -0.006433 -0.000310  0.079736  0.155931
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
#Slicinng of the data
df.iloc[0]
# Out:
# eventid       197000000001
# iyear                 1970
# imonth                   7
# iday                     2
# approxdate               0
#                   ...
# INT_LOG                  0
# INT_IDEO                 0
# INT_MISC                 0
# INT_ANY                  0
# related                  0
# Name: 0, Length: 135, dtype: object

# %%
#Printing States with the most attacks
print ('States with the most attacks:\n',df['provstate'].value_counts().head(10))
# Out:
# States with the most attacks:
#  Baghdad               7645
# Northern Ireland      4497
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3205
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Lima                  2615
# Name: provstate, dtype: int64

# %%
#Printing cities with the most attacks
print ('city with the most attacks:\n',df['city'].value_counts().head(10))
# Out:
# city with the most attacks:
#  Baghdad         7589
# Unknown         7534
# Karachi         2651
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1580
# San Salvador    1558
# Istanbul        1048
# Name: city, dtype: int64

# %%
#Piechart of attack type
plt.figure(figsize=(10,10))
df['attacktype1_txt'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
#Piechart of regions
plt.figure(figsize=(10,10))
df['region_txt'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
#Bargraph of number of terrorist activities by regions
plt.subplots(figsize=(15,6))
sns.countplot('region_txt',data=df,palette='inferno',order=df['region_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Regions')
plt.title('Terrerist activity by region')
plt.show()

# %%
#Bargraph of number of terrorist activities by year
plt.subplots(figsize=(15,6))
sns.countplot('iyear',data=df,palette='inferno',order=df['iyear'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.show()

# %%
#Finding frequency of attacks throughout the year
plt.subplots(figsize=(15,6))
sns.countplot(x=df['iyear'],hue='success',data=df)
plt.xticks(rotation=90)
plt.xlabel('iyear')
plt.show()

# %%
#Bargraph about most frequently tachnique of attack 
plt.subplots(figsize=(15,6))
sns.countplot('attacktype1_txt',data=df,palette='inferno',order=df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Attack Type')
plt.show()

# %%
#Plotting histogram
df.hist(figsize=(35,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C41DD6CE50>,
# ...
#       dtype=object)

# %%
#Double bargraph of countries and attacks
attack=df['country_txt'].value_counts()[:15].to_frame()
attack.columns=['Attacks']
kill=df.groupby('country_txt')['nkillter'].sum().to_frame()
attack.merge(kill,left_index=True,right_index=True).plot.bar(width=0.7)
fig=plt.gcf()
fig.set_size_inches(16,5)
plt.show()

# %%
#Bargraph of highest terrorism attack in the country
plt.subplots(figsize=(10,20))
sns.barplot(df['country_txt'].value_counts()[:15].index,df['country_txt'].value_counts()[:15].values)
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.show()

# %%
#Bargraph of highest terrorism attack in the country
plt.subplots(figsize=(50,20))
sns.countplot('country_txt',data=df,palette='inferno',order=df['country_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.show()

# %%
#Displaying only first five countries
plt.subplots(figsize=(10,10))
years=df.iyear.value_counts().head()
plt.bar(years.index,years.values)
plt.title('Countries')
# Out:
# Text(0.5, 1.0, 'Countries')

# %%
#Displaying only first five attack type
plt.subplots(figsize=(10,10))
attack=df.attacktype1_txt.value_counts().head()
plt.bar(attack.index,years.values)
plt.title('Countries')
# Out:
# Text(0.5, 1.0, 'Countries')

# %%
#Terrorist activities by region in each year by crosstab
pd.crosstab(df.iyear,df.region_txt).plot(kind='area',figsize=(20,10))
plt.title('terrorist acitivities by region in each year')
plt.ylabel('Number of attacks')
plt.show()

# %% [markdown]
# Conclusion:
#
# Countries with the highest number of Terrorist Artacks: Iraq
# Region with the highest number of Terrorist Attacks: Middle East & North Africa
# Maximum number of people killed by a single terrorist attack are: 1570 in iraq
# Year with the more attacks: 2014
# Month with the most Amacks: 5
# Most Atack types: BombingExplosions
# Year with highest number of frequencies of attacks : 2014
